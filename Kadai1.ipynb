# %% [markdown]
# <a href="https://colab.research.google.com/github/TMYH0812/SAMURAI-TERAKOYA/blob/main/Kadai1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 連想配列を作成
personal_data = {"name": "侍太郎", "age": 36, "gender": "男性"}

# キー「name」の値を表示
print(personal_data["name"])

# 連想配列全体を表示
print(personal_data)

# キー「age」の値を更新
personal_data["age"] = 37

# 新しく要素（キーと値）を追加
personal_data["address"] = "東京都"

# 連想配列全体を表示
print(personal_data)
# Out:
# 侍太郎
# {'name': '侍太郎', 'age': 36, 'gender': '男性'}
# {'name': '侍太郎', 'age': 37, 'gender': '男性', 'address': '東京都'}

# %%
from typing import AsyncIterable
# 台形の面積の計算
length = 10
width = 20
height = 5
volume = (number1 + number2) * height / 2
unit = "㎠"


print(str(volume) + unit)
# Out:
# 75.0㎠
